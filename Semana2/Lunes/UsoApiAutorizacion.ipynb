# %%
import pandas as pd
import requests

#url de la api - con autorizacion
API_KEY="d4IOpopHV4hhEtRRvTRyTTb1UoIA5DVTPeeW1g0Y"

url=f"https://api.nasa.gov/planetary/apod?api_key={API_KEY}"

respuesta=requests.get(url)

if respuesta.status_code==200:
    print("\nConexion exitosa con la API")
    datos=respuesta.json()
    print("Titulo: ",datos["title"])
    print("Fecha: ",datos["date"])
    print("URL de la imagen: ",datos["url"])
    
else:
    
    print("Error: ",respuesta.status_code)
# Out:
# Conexion exitosa con la API
# Titulo:  NGC 7635: The Bubble Nebula
# Fecha:  2026-07-27
# URL de la imagen:  https://apod.nasa.gov/apod/image/2607/Bubble_Piechnik_960.jpg
